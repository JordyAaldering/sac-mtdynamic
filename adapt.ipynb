# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style('darkgrid', rc={'ytick.left' : True})
pal = sns.color_palette(palette='icefire')
primary = pal[1]
secondary = pal[5]
highlight = pal[0]

# %%
path = 'results_sel265k/nbody_adapt.csv'
df = pd.read_csv(path)
df
# Out:
#      threads     power   runtime    energy
# 0         16  31250000  0.152542  0.004850
# 1         16  36125000  0.139274  0.004993
# 2         16  41000000  0.125729  0.005154
# 3         16  46000000  0.116897  0.005377
# 4         16  50875000  0.112624  0.005715
# ..       ...       ...       ...       ...
# 355       16  39375000  0.134446  0.005022
# 356       16  39625000  0.134395  0.005017
# 357       16  39750000  0.133919  0.005036
# 358       16  40250000  0.106420  0.006639
# 359       16  40750000  0.106722  0.006617
#
# [360 rows x 4 columns]

# %%
ax = sns.lineplot(df, x=df.index, y='power')
ax.set_ylim((0,None))
plt.show()

# %%
ax = sns.lineplot(df, x=df.index, y='energy')
ax.set_ylim((0,None))
plt.show()

# %%
ax = sns.lineplot(df, x=df.index, y='runtime')
ax.set_ylim((0,None))
plt.show()
