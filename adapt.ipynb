# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style('darkgrid', rc={'ytick.left' : True})
pal = sns.color_palette(palette='icefire')
primary = pal[1]
secondary = pal[5]
highlight = pal[0]

# %%
path = 'results_sel265k/adapt_nbody.csv'
df = pd.read_csv(path, sep=' ')
df['power'] /= 1e6
df
# Out:
#      threads   power   runtime    energy
# 0          8  12.500  0.501785  0.006011
# 1          8  18.375  0.501221  0.005891
# 2          8  24.250  0.501173  0.005876
# 3          8  30.250  0.500825  0.005858
# 4          8  36.125  0.500593  0.005851
# ..       ...     ...       ...       ...
# 232        8  12.500  0.500791  0.005865
# 233        8  12.500  0.501128  0.005862
# 234        8  12.500  0.500904  0.005882
# 235        8  12.500  0.500293  0.005862
# 236        8  12.500  0.500402  0.005863
#
# [237 rows x 4 columns]

# %%
ax = sns.lineplot(df, x=df.index, y='power')
ax.set_ylim((0,None))
plt.show()

# %%
ax = sns.lineplot(df, x=df.index, y='energy')
ax.set_ylim((0,None))
plt.show()

# %%
ax = sns.lineplot(df, x=df.index, y='runtime')
ax.set_ylim((0,None))
plt.show()
