# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from glob import glob

# %% [markdown]
# # Matmul

# %%
frames = []

for path in glob('laptop//matmul_fixed_*.csv'):
    print('Read:', path)
    df = pd.read_csv(path)

    uids = df['uid'].unique()
    funs = ['iota', 'transpose', 'matmul']
    rename = dict(zip(uids, funs))
    df.replace({'uid': rename}, inplace=True)

    df['size'] = int(path.split('_')[2])

    frames.append(df)

df = pd.concat(frames)
df
# Out:
# Read: laptop/matmul_fixed_2500_2.csv
# Read: laptop/matmul_fixed_2500_8.csv
# Read: laptop/matmul_fixed_2500_4.csv
# Read: laptop/matmul_fixed_2500_16.csv
# Read: laptop/matmul_fixed_2500_1.csv
#           uid  threads    runtime   usertime      energy  size
# 1   transpose        2   0.014393   0.028389    0.724709  2500
# 2      matmul        2   6.255580  12.510280  196.281660  2500
# 3   transpose        2   0.007449   0.014454    0.174094  2500
# 4      matmul        2   6.145245  12.289829  170.515960  2500
# 5   transpose        2   0.007463   0.014442    0.144967  2500
# ..        ...      ...        ...        ...         ...   ...
# 36     matmul        1  11.639088  11.637298  226.989440  2500
# 37  transpose        1   0.013847   0.013846    0.184072  2500
# 38     matmul        1  11.396350  11.394567  209.944580  2500
# 39  transpose        1   0.013743   0.013742    0.185431  2500
# 40     matmul        1  11.550507  11.548758  232.976360  2500
#
# [200 rows x 6 columns]

# %%
sns.barplot(df[df['uid'] == 'matmul'], x='threads', y='runtime')
plt.show()

# %%
sns.barplot(df[df['uid'] == 'matmul'], x='threads', y='energy')
plt.show()

# %%
sns.barplot(df[df['uid'] == 'transpose'], x='threads', y='runtime')
plt.show()

# %%
sns.barplot(df[df['uid'] == 'transpose'], x='threads', y='energy')
plt.show()

# %% [markdown]
# # N-Body

# %%
frames = []

for path in glob('laptop//nbody_fixed_*.csv'):
    print('Read:', path)
    df = pd.read_csv(path)

    uids = df['uid'].unique()
    funs = ['iota', 'acc']
    rename = dict(zip(uids, funs))
    df.replace({'uid': rename}, inplace=True)

    df['size'] = int(path.split('_')[2])

    frames.append(df)

df = pd.concat(frames)
df
# Out:
# Read: laptop/nbody_fixed_50000_16.csv
# Read: laptop/nbody_fixed_50000_8.csv
# Read: laptop/nbody_fixed_50000_1.csv
# Read: laptop/nbody_fixed_50000_4.csv
# Read: laptop/nbody_fixed_50000_2.csv
#             uid  threads   runtime  usertime     energy   size
# 0          iota       16  0.004981  0.064739   0.331739  50000
# 1           acc       16  0.321360  4.735460  20.395964  50000
# 2    -201581600       16  0.000180  0.000168   0.000000  50000
# 3    -201583248       16  0.000143  0.015202   0.000000  50000
# 4    -201584864       16  0.000146  0.000137   0.000000  50000
# ..          ...      ...       ...       ...        ...    ...
# 196   877124528        2  0.000086  0.000088   0.000000  50000
# 197   877122720        2  0.000059  0.000059   0.000000  50000
# 198   877121072        2  0.000044  0.000044   0.000000  50000
# 199   877119456        2  0.000065  0.000065   0.000000  50000
# 200   877117760        2  0.000045  0.000045   0.000000  50000
#
# [1005 rows x 6 columns]

# %%
sns.barplot(df[df['uid'] == 'acc'], x='threads', y='runtime')
plt.show()

# %%
sns.barplot(df[df['uid'] == 'acc'], x='threads', y='energy')
plt.show()
